# %% [markdown]
# # Data Visualization with Python
# # Lecture 2: Example of Bad Data Visualization
#
# Instructor: **Md Shahidullah Kawsar**
# <br> Data Scientist, IDARE, Houston, TX, USA
#
# References:
# [1] https://www.businessinsider.com/the-27-worst-charts-of-all-time-2013-6
# <br>[2] https://badvisualisations.tumblr.com/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
